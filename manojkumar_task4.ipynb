# %% [markdown]
# <a href="https://colab.research.google.com/gist/manojkumark04/9aaf43bd5897624a2b008e165e4ac2c5/manojkumar_task4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###### Assessment

# %% [markdown]
# ###### I am going to provide two .csv files , you are supposed to work on them and have to provide solutions to the following problems

# %% [markdown]
# ###### import necessary libraries

# %%
import pandas as pd
import csv
import numpy as np
import json

# %%
a = pd.read_csv("college_1.csv", encoding='utf-8')
b = pd.read_csv("college_2.csv", encoding='utf-8')
print(a)
b
# Out:
#               Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0        A.Dharani    82.0   20.0              24500           24500
# 1      V.JEEVITHA     82.0   20.0              21740           21740
# 2      HEMAVATHI.R   100.0  100.0              19680           19680
# 3      Mugunthan S   100.0   47.0              10610           10610
# 4      Sathammai.S   100.0    8.0               8980            8980
# ..             ...     ...    ...                ...             ...
# 79    KarthikeyanS    45.0    0.0                  0               0
# 80        BARATH.P    29.0    0.0                  0               0
# 81   N.Ajith kumar    82.0    0.0                  0               0
# 82    mohamed nabi     0.0    0.0                  0               0
# 83  yaser ahamed.A     0.0   27.0                  0               0
#
#                                 Department  Rising
# 0         Computer Science and Engineering       0
# ...

# %% [markdown]
# ###### merge those two csv files (after getting as dataframes, get them as a single dataframe)

# %%
df1 = pd.DataFrame(a)
df2 = pd.DataFrame(b)
frame = [df1,df2]
df3 = pd.concat(frame, ignore_index=True)
df3
# Out:
#               Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0        A.Dharani    82.0   20.0              24500           24500
# 1      V.JEEVITHA     82.0   20.0              21740           21740
# 2      HEMAVATHI.R   100.0  100.0              19680           19680
# 3      Mugunthan S   100.0   47.0              10610           10610
# 4      Sathammai.S   100.0    8.0               8980            8980
# ..             ...     ...    ...                ...             ...
# 114  praveen raj j    24.0    0.0               2380            2380
# 115     AMARNATH D    -1.0   12.0               1890            1890
# 116           bala    32.0    0.0               1720            1720
# 117           XY Z    -1.0   -1.0                  0               0
# 118      Hariharan    -1.0   -1.0                  0               0
#
#                                     Department  Rising  python_en  \
# 0             Computer Science and Engineering       0        NaN
# ...

# %% [markdown]
# ###### Take each csv file , split that csv file into multiple categories (example csv files are added in the repo)

# %%
a1 = df1.loc[:,"python":"Rising"]
a2 = a1.drop(['Department'], axis=1)
b1 = df2.loc[:,"python":"Rising"]
b2 = b1.drop(['Department'], axis=1)
print(a2)
print(b2)

# %% [markdown]
# ###### consider if the codekata score exceeds 15000 points(present week) then make a csv on those observations as Exceeded expectations.csv

# %%
exceed = df3[df3['CodeKata Score'] > 15000]
exceed

# %% [markdown]
# ###### if  10000<codekata score<15000   (Reached_expectations.csv)

# %%
reached = df3[df3['CodeKata Score'] > 15000]
reached = (reached.dropna(axis='columns'))
reached = reached.loc[:, (reached != 0).any(axis=0)]
reached.to_csv('Reached_expectations.csv')

# %% [markdown]
# ###### if  7000<codekata score<10000   (Needs_Improvement.csv)

# %%
improvement = df3[(df3['CodeKata Score'] < 7000 ) & (df3['CodeKata Score'] < 10000)]
improvement = (reached.dropna(axis='columns'))
improvement = improvement.loc[:, (improvement != 0).any(axis=0)]
improvement.to_csv('Needs_Improvement.csv')
improvement

# %% [markdown]
# ###### if  codekate score < 7000        (Unsatisfactory.csv)

# %%
unsatisfactory = df3[df3['CodeKata Score'] < 7000]
unsatisfactory = (unsatisfactory.dropna(axis='columns'))
unsatisfactory = unsatisfactory.loc[:, (unsatisfactory != 0).any(axis=0)]
unsatisfactory.to_csv('Unsatisfactory.csv')
unsatisfactory

# %% [markdown]
# ###### Average of previous week geekions vs this week geekions (i.e Previous Geekions vs CodeKata Score)

# %%
geekions_average = df3["Previous Geekions"].mean()
CodeKata_average = df3["CodeKata Score"].mean()
print(CodeKata_average)
geekions_average
import matplotlib.pyplot as plt

fig, ax  = plt.subplots()
ax.bar([1, 2], [geekions_average, CodeKata_average], width= 0.5, tick_label=['Geekions_average', 'CodeKata_Average'], align='center')
# Out:
# 4051.764705882353
# 3842.3529411764707

# %% [markdown]
# ###### No of students participated

# %%
students_participated = df3.shape[0]
students_participated
# Out:
# 119

# %% [markdown]
# ###### #Average completion of python course or my_sql or python english or computational thinking

# %%
python_average = df3["python"].mean()
mysql_average = df3["mysql"].mean()
python_english_average = df3["python_en"].mean()
computational_average = df3["computational_thinking"].mean()
import matplotlib.pyplot as plt

fig, ax  = plt.subplots()
ax.bar([1,2,3,4], [python_average, mysql_average,python_english_average, computational_average], width= 0.5, tick_label=['Python', 'Mysql', 'Python_En', 'Computational'], align='center')
# Out:
# <BarContainer object of 4 artists>

# %% [markdown]
# ###### rising star of the week (top 3 candidate who performed well in that particular week)

# %%
Rising_star = df3.sort_values(by=['CodeKata Score'], ascending=False)
Rising_star.head(3)
# Out:
#           Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0    A.Dharani    82.0   20.0              24500           24500
# 1  V.JEEVITHA     82.0   20.0              21740           21740
# 2  HEMAVATHI.R   100.0  100.0              19680           19680
#
#                          Department  Rising  python_en  computational_thinking
# 0  Computer Science and Engineering       0        NaN                     NaN
# 1  Computer Science and Engineering       0        NaN                     NaN
# 2  Computer Science and Engineering       0        NaN                     NaN

# %% [markdown]
# ###### Shining stars of the week (top 3 candidates who has highest geekions)

# %%
Shining_star = df3.sort_values(by=['Previous Geekions'], ascending=False)
Shining_star.head(3)
# Out:
#           Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0    A.Dharani    82.0   20.0              24500           24500
# 1  V.JEEVITHA     82.0   20.0              21740           21740
# 2  HEMAVATHI.R   100.0  100.0              19680           19680
#
#                          Department  Rising  python_en  computational_thinking
# 0  Computer Science and Engineering       0        NaN                     NaN
# 1  Computer Science and Engineering       0        NaN                     NaN
# 2  Computer Science and Engineering       0        NaN                     NaN

# %% [markdown]
# ###### Department wise codekata performence (pie chart)

# %%
df3
df3.groupby(['Department']).sum().plot(kind='pie', y='CodeKata Score',autopct='%1.0f%%', title='Department wise codekata performence')

# %% [markdown]
# ###### Department wise toppers (horizantal bar graph or any visual representations of your choice)

# %%
df3.plot.barh(x='Department', y='CodeKata Score')
